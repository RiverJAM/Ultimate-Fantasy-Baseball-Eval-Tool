# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame
pitchers = pd.read_csv('data/Merged_Data/pitchers_all_data.csv')
hitters = pd.read_csv('data/Merged_Data/hitters_all_data.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# matplotlib histogram
plt.hist(pitchers['razz_value'], color = 'blue', edgecolor = 'black',
         bins = int(180/5))

# seaborn histogram
sns.distplot(pitchers['razz_value'], hist=True, kde=False, 
             bins=int(180/5), color = 'blue',
             hist_kws={'edgecolor':'black'})
# Add labels
plt.title('Histogram of razz value')
plt.xlabel('razz value')
plt.ylabel('Frequency')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Frequency')

# %%
## List of the colums when you need them to pull certain stats

# col = pitchers.columns
# for col in col:
#     print(col)

# %%
years = [2019, 2015, 2014, 2017, 2013, 2012, 2016, 2018, 2020]
years
# Out:
# [2019, 2015, 2014, 2017, 2013, 2012, 2016, 2018, 2020]

# %%
col = pitchers.columns
for col in col:
    print(col)
# Out:
# ft_score
# avg
# razz_value
# ﻿idfg
# season
# name
# team
# age
# w
# l
# war
# era
# g
# gs
# cg
# sho
# sv
# bs
# ip
# tbf
# h
# r
# er
# hr
# bb
# ibb
# hbp
# wp
# bk
# so
# gb
# fb
# ld
# iffb
# balls
# strikes
# pitches
# rs
# ifh
# bu
# buh
# kper9
# bbper9
# kperbb
# hper9
# hrper9
# avg.1
# whip
# babip
# lobpercen
# fip
# gbperfb
# ldpercen
# gbpercen
# fbpercen
# iffbpercen
# hrperfb
# ifhpercen
# buhpercen
# starting
# start_ip
# relieving
# relief_ip
# rar
# dollars
# tera
# xfip
# wpa
# wpa1
# wpa2
# re24
# rew
# pli
# inli
# gmli
# exli
# pulls
# wpaperli
# clutch
# FBpercen 2
# fbv
# slpercen
# slv
# ctpercen
# ctv
# cbpercen
# cbv
# chpercen
# chv
# sfpercen
# sfv
# knpercen
# knv
# xxpercen
# popercen
# wfb
# wsl
# wct
# wcb
# wch
# wsf
# wkn
# wfbperc
# wslperc
# wctperc
# wcbperc
# wchperc
# wsfperc
# wknperc
# o_swingpercen
# z_swingpercen
# swingpercen
# o_contactpercen
# z_contactpercen
# contactpercen
# zonepercen
# f_strikepercen
# swstrpercen
# hld
# sd
# md
# era_
# fip_
# xfip_
# kpercen
# bbpercen
# siera
# rsper9
# e_f
# FApercen (pfx)
# FTpercen (pfx)
# FCpercen (pfx)
# FSpercen (pfx)
# FOpercen (pfx)
# SIpercen (pfx)
# SLpercen (pfx)
# CUpercen (pfx)
# KCpercen (pfx)
# EPpercen (pfx)
# CHpercen (pfx)
# SCpercen (pfx)
# KNpercen (pfx)
# UNpercen (pfx)
# vFA (pfx)
# vFT (pfx)
# vFC (pfx)
# vFS (pfx)
# vFO (pfx)
# vSI (pfx)
# vSL (pfx)
# vCU (pfx)
# vKC (pfx)
# vEP (pfx)
# vCH (pfx)
# vSC (pfx)
# vKN (pfx)
# FA_X (pfx)
# FT_X (pfx)
# FC_X (pfx)
# FS_X (pfx)
# FO_X (pfx)
# SI_X (pfx)
# SL_X (pfx)
# CU_X (pfx)
# KC_X (pfx)
# EP_X (pfx)
# CH_X (pfx)
# SC_X (pfx)
# KN_X (pfx)
# FA_Z (pfx)
# FT_Z (pfx)
# FC_Z (pfx)
# FS_Z (pfx)
# FO_Z (pfx)
# SI_Z (pfx)
# SL_Z (pfx)
# CU_Z (pfx)
# KC_Z (pfx)
# EP_Z (pfx)
# CH_Z (pfx)
# SC_Z (pfx)
# KN_Z (pfx)
# wFA (pfx)
# wFT (pfx)
# wFC (pfx)
# wFS (pfx)
# wFO (pfx)
# wSI (pfx)
# wSL (pfx)
# wCU (pfx)
# wKC (pfx)
# wEP (pfx)
# wCH (pfx)
# wSC (pfx)
# wKN (pfx)
# wFAperC (pfx)
# wFTperC (pfx)
# wFCperC (pfx)
# wFSperC (pfx)
# wFOperC (pfx)
# wSIperC (pfx)
# wSLperC (pfx)
# wCUperC (pfx)
# wKCperC (pfx)
# wEPperC (pfx)
# wCHperC (pfx)
# wSCperC (pfx)
# wKNperC (pfx)
# O_Swingpercen (pfx)
# Z_Swingpercen (pfx)
# Swingpercen (pfx)
# O_Contactpercen (pfx)
# Z_Contactpercen (pfx)
# Contactpercen (pfx)
# Zonepercen (pfx)
# pace
# ra9_war
# bip_wins
# lob_wins
# fdp_wins
# Age Rng
# k_bbpercen
# pullpercen
# centpercen
# oppopercen
# softpercen
# medpercen
# hardpercen
# kwera
# ttopercen
# CHpercen (pi)
# CSpercen (pi)
# CUpercen (pi)
# FApercen (pi)
# FCpercen (pi)
# FSpercen (pi)
# KNpercen (pi)
# SBpercen (pi)
# SIpercen (pi)
# SLpercen (pi)
# XXpercen (pi)
# vCH (pi)
# vCS (pi)
# vCU (pi)
# vFA (pi)
# vFC (pi)
# vFS (pi)
# vKN (pi)
# vSB (pi)
# vSI (pi)
# vSL (pi)
# vXX (pi)
# CH_X (pi)
# CS_X (pi)
# CU_X (pi)
# FA_X (pi)
# FC_X (pi)
# FS_X (pi)
# KN_X (pi)
# SB_X (pi)
# SI_X (pi)
# SL_X (pi)
# XX_X (pi)
# CH_Z (pi)
# CS_Z (pi)
# CU_Z (pi)
# FA_Z (pi)
# FC_Z (pi)
# FS_Z (pi)
# KN_Z (pi)
# SB_Z (pi)
# SI_Z (pi)
# SL_Z (pi)
# XX_Z (pi)
# wCH (pi)
# wCS (pi)
# wCU (pi)
# wFA (pi)
# wFC (pi)
# wFS (pi)
# wKN (pi)
# wSB (pi)
# wSI (pi)
# wSL (pi)
# wXX (pi)
# wCHperC (pi)
# wCSperC (pi)
# wCUperC (pi)
# wFAperC (pi)
# wFCperC (pi)
# wFSperC (pi)
# wKNperC (pi)
# wSBperC (pi)
# wSIperC (pi)
# wSLperC (pi)
# wXXperC (pi)
# O_Swingpercen (pi)
# Z_Swingpercen (pi)
# Swingpercen (pi)
# O_Contactpercen (pi)
# Z_Contactpercen (pi)
# Contactpercen (pi)
# Zonepercen (pi)
# Pace (pi)
# frm
# kper9plus
# bbper9plus
# hper9plus
# hrper9plus
# avgplus
# whipplus
# babipplus
# lobpercenplus
# kpercenplus
# bbpercenplus
# ldpercenplus
# gbpercenplus
# fbpercenplus
# hrperfbpercenplus
# pullpercenplus
# centpercenplus
# oppopercenplus
# softpercenplus
# medpercenplus
# hardpercenplus
# ev
# la
# barrels
# barrelpercen
# maxev
# hardhit
# hardhitpercen
# events

# %%
from sklearn.linear_model import LinearRegression

for year in years:
    db = pitchers.loc[ (pitchers['season']==year)]
    db = db[['razz_value','name', 'avg']].dropna()

    X = db.avg.values.reshape(-1, 1)
    y = db.razz_value.values.reshape(-1, 1)


    print("Shape: ", X.shape, y.shape)
    X
    from sklearn.linear_model import LinearRegression

    ### BEGIN SOLUTION

    model = LinearRegression()
    model.fit(X, y)
    print('Weight coefficients: ', model.coef_)
    print('y-axis intercept: ', model.intercept_)
    x_min = np.array([[X.min()]])
    x_max = np.array([[X.max()]])

    y_min = model.predict(x_min)
    y_max = model.predict(x_max)
    from sklearn.metrics import mean_squared_error, r2_score

    # Use our model to predict a value
    predicted = model.predict(X)

    # Score the prediction with mse and r2
    mse = mean_squared_error(y, predicted)
    r2 = r2_score(y, predicted)

    print(f"Mean Squared Error (MSE): {mse}")
    print(f"R-squared (R2 ): {r2}")
    # Overall Score for the model
    how_good_is_it = model.score(X, y)
    print(f"score is {how_good_is_it}")
    plt.scatter(X, y, c='blue')
    plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='red')
    plt.show()
# Out:
# Shape:  (315, 1) (315, 1)
# Weight coefficients:  [[-0.01886578]]
# y-axis intercept:  [6.0626596]
# Mean Squared Error (MSE): 83.5627022031933
# R-squared (R2 ): 0.2426737526758317
# score is 0.2426737526758317
# Shape:  (173, 1) (173, 1)
# Weight coefficients:  [[-0.05258752]]
# y-axis intercept:  [14.84587783]
# Mean Squared Error (MSE): 79.46116674418883
# R-squared (R2 ): 0.3685676169654071
# score is 0.3685676169654071
# Shape:  (155, 1) (155, 1)
# Weight coefficients:  [[-0.04642457]]
# y-axis intercept:  [11.32855738]
# Mean Squared Error (MSE): 108.46213319902569
# R-squared (R2 ): 0.1957164088474337
# score is 0.1957164088474337
# Shape:  (163, 1) (163, 1)
# Weight coefficients:  [[-0.04606517]]
# y-axis intercept:  [11.56424634]
# Mean Squared Error (MSE): 91.51990942848802
# R-squared (R2 ): 0.23289377522493426
# score is 0.23289377522493426
# Shape:  (142, 1) (142, 1)
# Weight coefficients:  [[-0.06327634]]
# y-axis intercept:  [14.61657262]
# Mean Squared Error (MSE): 98.85886373257256
# R-squared (R2 ): 0.23338137229898392
# score is 0.23338137229898392
# Shape:  (153, 1) (153, 1)
# Weight coefficients:  [[-0.06821058]]
# y-axis intercept:  [14.33991698]
# Mean Squared Error (MSE): 104.88393784632777
# R-squared (R2 ): 0.18310804790774027
# score is 0.18310804790774027
# Shape:  (172, 1) (172, 1)
# Weight coefficients:  [[-0.04442635]]
# y-axis intercept:  [11.44103976]
# Mean Squared Error (MSE): 90.1459956509473
# R-squared (R2 ): 0.22646132223775917
# score is 0.22646132223775917
# Shape:  (287, 1) (287, 1)
# Weight coefficients:  [[-0.02022135]]
# y-axis intercept:  [6.10561607]
# Mean Squared Error (MSE): 103.1281905932953
# R-squared (R2 ): 0.2887389161980467
# score is 0.2887389161980467
# Shape:  (137, 1) (137, 1)
# Weight coefficients:  [[-0.02092672]]
# y-axis intercept:  [6.83875429]
# Mean Squared Error (MSE): 153.08765848457855
# R-squared (R2 ): 0.12642155311640857
# score is 0.12642155311640857

# %%
year =2019
db = pitchers.loc[ (pitchers['season']==year)]
db['adp_ranks'] = db['avg'].rank(ascending=True)
db = db[['razz_value','name', 'adp_ranks']].dropna()

X = db.adp_ranks.values.reshape(-1, 1)
y = db.razz_value.values.reshape(-1, 1)


print("Shape: ", X.shape, y.shape)
X
from sklearn.linear_model import LinearRegression

### BEGIN SOLUTION

model = LinearRegression()
model.fit(X, y)
print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
x_min = np.array([[X.min()]])
x_max = np.array([[X.max()]])

y_min = model.predict(x_min)
y_max = model.predict(x_max)
from sklearn.metrics import mean_squared_error, r2_score

# Use our model to predict a value
predicted = model.predict(X)

# Score the prediction with mse and r2
mse = mean_squared_error(y, predicted)
r2 = r2_score(y, predicted)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# Overall Score for the model
how_good_is_it = model.score(X, y)
print(f"score is {how_good_is_it}")
plt.scatter(X, y, c='blue')
plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='red')
plt.xlabel("ADP")
plt.ylabel("Razz Value")
plt.savefig('2019ADP.png')
plt.show()
# Out:
# Shape:  (315, 1) (315, 1)
# Weight coefficients:  [[-0.05830602]]
# y-axis intercept:  [6.74628712]
# Mean Squared Error (MSE): 82.05313198021553
# R-squared (R2 ): 0.2563549420330181
# score is 0.2563549420330181
# <ipython-input-8-6ec12d7d2bbc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db['adp_ranks'] = db['avg'].rank(ascending=True)

# %%
'era', 'whip','bbpercen', 'w','l', 'so', 'sv','hld','age','war', 'g','ip', 'hr', 'bb', 'ibb', 'hbp', 'babip','fip','gbpercen', 'fbpercen'
# Out:
# ('era',
#  'whip',
#  'bbpercen',
#  'w',
#  'l',
#  'so',
#  'sv',
#  'hld',
#  'age',
#  'war',
#  'g',
#  'ip',
#  'hr',
#  'bb',
#  'ibb',
#  'hbp',
#  'babip',
#  'fip',
#  'gbpercen',
#  'fbpercen')

# %%
import statsmodels.api as sm
from scipy import stats

# %%
years =['2012','2013','2014', '2015', '2016']
model = LinearRegression()

for year in years:
    SeasonOne = pitchers.loc[ (pitchers['season']==int(year))]
    SeasonTwo = pitchers.loc[ (pitchers['season']==(int(year)+1))]
    SeasonThree = pitchers.loc[ (pitchers['season']==(int(year)+2))]
    RazzSeason = pitchers.loc[ (pitchers['season']==(int(year)+3))]

    SeasonOne = SeasonOne[['era', 'whip','bbpercen','name', 'w','l', 'so', 'sv','hld','age','war', 'g','ip', 'hr', 'bb', 'ibb', 'hbp', 'babip','xfip','gbpercen', 'fbpercen' ]]
    SeasonTwo = SeasonTwo[['era', 'whip','bbpercen','name', 'w','l', 'so', 'sv','hld','age','war', 'g','ip', 'hr', 'bb', 'ibb', 'hbp', 'babip','xfip','gbpercen', 'fbpercen' ]]
    SeasonThree = SeasonThree[['era', 'whip','bbpercen','name', 'w','l', 'so', 'sv','hld','age','war', 'g','ip', 'hr', 'bb', 'ibb', 'hbp', 'babip','xfip','gbpercen', 'fbpercen' ]]

    RazzSeason = RazzSeason[['razz_value','name']].dropna()
    RazzSeason = RazzSeason.merge(SeasonOne , on='name')
    RazzSeason = RazzSeason.merge(SeasonTwo , on='name')
    RazzSeason = RazzSeason.merge(SeasonThree , on='name')
    
RazzSeason.head()
# Out:
#    razz_value               name  era_x  whip_x  bbpercen_x  w_x  l_x  so_x  \
# 0        42.7   Justin Verlander   3.04    1.00       0.063   16    9   254
# 1        40.9        Gerrit Cole   3.88    1.44       0.071    7   10    98
# 2        26.2  Stephen Strasburg   3.60    1.10       0.074   15    4   183
# 3        25.2       Jacob deGrom   3.04    1.20       0.060    7    8   143
# 4        24.8       Zack Greinke   4.37    1.27       0.061   13    7   134
#
#    sv_x  hld_x  ...   g     ip  hr  bb  ibb  hbp  babip  xfip  gbpercen  \
# 0     0      0  ...  34  214.0  28  37    0    8  0.272  3.03     0.291
# 1     0      0  ...  32  200.1  19  64    0    7  0.286  3.04     0.360
# 2     0      0  ...  22  130.0  18  38    2    8  0.309  3.28     0.436
# 3     0      0  ...  32  217.0  10  46    3    5  0.281  2.60     0.464
# 4     0      0  ...  33  207.2  28  43    3    6  0.272  3.44     0.451
#
#    fbpercen
# 0     0.514
# 1     0.427
# 2     0.341
# 3     0.316
# 4     0.319
#
# [5 rows x 62 columns]

# %%
# col = [RazzSeason.columns]
# for col in col:
#     print(col)

# %%
Nineteen = pitchers.loc[ (pitchers['season']==2019)]
ADP_Nineteen = Nineteen[['name','avg']]
ADP_Nineteen
# Out:
#                       name    avg
# 0     Daniel Ponce de Leon  724.7
# 19        Justin Verlander   21.2
# 22             Gerrit Cole   26.8
# 57       Stephen Strasburg   58.0
# 63            Jacob deGrom   10.4
# ...                    ...    ...
# 1677            David Hess  744.5
# 1685     Jordan Zimmermann  512.8
# 1693         Shelby Miller  686.7
# 1699           Dan Straily  573.0
# 1704         Edwin Jackson  770.3
#
# [316 rows x 2 columns]

# %%
years =['2012','2013','2014', '2015', '2016']
model = LinearRegression()

for year in years:
    SeasonOne = pitchers.loc[ (pitchers['season']==int(year))]
    SeasonTwo = pitchers.loc[ (pitchers['season']==(int(year)+1))]
    SeasonThree = pitchers.loc[ (pitchers['season']==(int(year)+2))]
    RazzSeason = pitchers.loc[ (pitchers['season']==(int(year)+3))]

    SeasonOne = SeasonOne[['era', 'whip','bbpercen','name', 'w','l', 'so', 'sv','hld','age','war', 'g','ip', 'hr', 'bb', 'ibb', 'hbp', 'babip','xfip','gbpercen', 'fbpercen' ]]
    SeasonTwo = SeasonTwo[['era', 'whip','bbpercen','name', 'w','l', 'so', 'sv','hld','age','war', 'g','ip', 'hr', 'bb', 'ibb', 'hbp', 'babip','xfip','gbpercen', 'fbpercen' ]]
    SeasonThree = SeasonThree[['era', 'whip','bbpercen','name', 'w','l', 'so', 'sv','hld','age','war', 'g','ip', 'hr', 'bb', 'ibb', 'hbp', 'babip','xfip','gbpercen', 'fbpercen' ]]

    RazzSeason = RazzSeason[['razz_value','name']].dropna()
    RazzSeason = RazzSeason.merge(SeasonOne , on='name')
    RazzSeason = RazzSeason.merge(SeasonTwo , on='name')
    RazzSeason = RazzSeason.merge(SeasonThree , on='name')
    X= RazzSeason[['era_x', 'whip_x', 'w_x', 'l_x',
         'hld_x', 'war_x', 'ip_x', 'hr_x',
       'bb_x', 'ibb_x', 'hbp_x', 'xfip_x', 'gbpercen_x',
       'fbpercen_x', 'era_y', 'whip_y', 'w_y', 'l_y', 'so_y',
       'sv_y', 'hld_y', 'war_y', 'ip_y', 'hr_y', 'bb_y',
       'ibb_y', 'hbp_y', 'xfip_y', 'gbpercen_y', 'fbpercen_y',
       'era', 'whip', 'w', 'l', 'so', 'sv', 'hld', 'age', 'war',
        'ip', 'hr', 'bb', 'ibb', 'hbp', 'xfip', 'gbpercen',
       'fbpercen']]
    y= RazzSeason[['razz_value']].to_numpy()
    
    

    # Fitting our model with all of our features in X
    model.fit(X, y)
    ## used as reference: https://stackoverflow.com/questions/56039406/how-can-i-display-the-weights-and-bias-from-linearregression

    score = model.score(X, y)
    print(f"R2 Score: {score}")
print(f" coef {model.coef_}")
print(f" int {model.intercept_}")
predictions = model.predict(X)
# Plot Residuals


plt.scatter(predictions, predictions - y)
plt.hlines(y=0, xmin=predictions.min(), xmax=predictions.max())
plt.show()

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
predictions = model.predict(X)
RazzSeason['predictions']= predictions
RazzSeason['predictions_ranks'] =RazzSeason['predictions'].rank(ascending=False)
RazzSeason['razz_ranks'] =RazzSeason['razz_value'].rank(ascending=False)

RazzSeason= RazzSeason.merge(ADP_Nineteen, on='name')
RazzSeason['adp_ranks'] =RazzSeason['avg'].rank(ascending=True)
RazzSeason['rating_diff']= ( RazzSeason['adp_ranks'] - RazzSeason['predictions_ranks'])
RazzSeason.head(10)
# Out:
# R2 Score: 0.9142946481079799
# R2 Score: 0.9333087606010227
# R2 Score: 0.8888060257985204
# R2 Score: 0.7789902167313947
# R2 Score: 0.8177695923940833
#  coef [[ 7.03797232e+00 -5.56246620e+01  6.24066354e-01 -8.59545185e-01
#   -8.71371335e-01  1.11747715e+01 -4.65172020e-01  1.39825846e+00
#    3.95852968e-01  2.55361558e+00 -6.03749856e-01  1.42087980e+01
#   -4.34043350e+01 -1.16513403e+02 -1.78641228e+00  5.66707116e-01
#   -2.68410809e+00 -4.50612609e-01  1.06517578e-01  7.53610908e-01
#    1.14591078e+00 -1.46629803e+01  8.74841092e-01 -2.08658819e+00
#   -4.25519076e-01  1.29430443e+00 -1.48465597e+00 -6.30749815e+00
#    5.41196071e+01  2.29951506e+01 -2.13217991e+00  1.63942206e+01
#   -1.38963509e+00  5.45398742e-01  2.73216469e-01 -8.06773364e-01
#   -5.69793380e-01  2.03429033e-01 -5.33615516e+00  6.59227340e-02
#   -1.14031719e+00 -6.24967086e-02 -5.18038586e-01  8.81931726e-02
#   -1.13799451e+01  3.25158605e+01  1.39476768e+02]]
#  int [-4.96637876]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.818
# Model:                            OLS   Adj. R-squared:                  0.532
# Method:                 Least Squares   F-statistic:                     2.864
# Date:                Wed, 10 Mar 2021   Prob (F-statistic):            0.00152
# Time:                        12:32:07   Log-Likelihood:                -241.82
# No. Observations:                  78   AIC:                             579.6
# Df Residuals:                      30   BIC:                             692.8
# Df Model:                          47
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -4.9664     99.635     -0.050      0.961    -208.449     198.516
# era_x          7.0380      3.392      2.075      0.047       0.111      13.965
# whip_x       -55.6247     23.786     -2.339      0.026    -104.203      -7.047
# w_x            0.6241      0.856      0.729      0.472      -1.125       2.373
# l_x           -0.8595      0.642     -1.339      0.191      -2.170       0.451
# hld_x         -0.8714      0.450     -1.938      0.062      -1.790       0.047
# war_x         11.1748      5.130      2.178      0.037       0.697      21.652
# ip_x          -0.4652      0.239     -1.947      0.061      -0.953       0.023
# hr_x           1.3983      0.806      1.734      0.093      -0.249       3.045
# bb_x           0.3959      0.248      1.596      0.121      -0.111       0.903
# ibb_x          2.5536      1.034      2.470      0.019       0.442       4.665
# hbp_x         -0.6037      0.493     -1.224      0.231      -1.611       0.404
# xfip_x        14.2088      7.305      1.945      0.061      -0.709      29.127
# gbpercen_x   -43.4043     66.153     -0.656      0.517    -178.507      91.699
# fbpercen_x  -116.5134     87.993     -1.324      0.195    -296.220      63.193
# era_y         -1.7864      4.189     -0.426      0.673     -10.342       6.769
# whip_y         0.5667     21.822      0.026      0.979     -43.999      45.132
# w_y           -2.6841      0.828     -3.242      0.003      -4.375      -0.993
# l_y           -0.4506      0.920     -0.490      0.628      -2.330       1.429
# so_y           0.1065      0.161      0.661      0.514      -0.223       0.436
# sv_y           0.7536      0.344      2.193      0.036       0.052       1.456
# hld_y          1.1459      0.832      1.376      0.179      -0.554       2.846
# war_y        -14.6630      6.087     -2.409      0.022     -27.093      -2.233
# ip_y           0.8748      0.293      2.988      0.006       0.277       1.473
# hr_y          -2.0866      1.031     -2.023      0.052      -4.193       0.020
# bb_y          -0.4255      0.335     -1.272      0.213      -1.109       0.258
# ibb_y          1.2943      0.896      1.445      0.159      -0.535       3.124
# hbp_y         -1.4847      0.698     -2.128      0.042      -2.910      -0.060
# xfip_y        -6.3075      8.388     -0.752      0.458     -23.439      10.824
# gbpercen_y    54.1196     69.673      0.777      0.443     -88.172     196.411
# fbpercen_y    22.9952     89.271      0.258      0.798    -159.320     205.311
# era           -2.1322      3.642     -0.585      0.563      -9.570       5.305
# whip          16.3942     24.210      0.677      0.503     -33.048      65.837
# w             -1.3896      0.750     -1.854      0.074      -2.921       0.141
# l              0.5454      0.970      0.562      0.578      -1.435       2.526
# so             0.2732      0.174      1.566      0.128      -0.083       0.629
# sv            -0.8068      0.370     -2.183      0.037      -1.562      -0.052
# hld           -0.5698      0.435     -1.309      0.200      -1.459       0.319
# age            0.2034      0.498      0.408      0.686      -0.815       1.221
# war           -5.3362      5.358     -0.996      0.327     -16.280       5.607
# ip             0.0659      0.239      0.275      0.785      -0.423       0.555
# hr            -1.1403      1.019     -1.120      0.272      -3.221       0.940
# bb            -0.0625      0.279     -0.224      0.824      -0.633       0.508
# ibb           -0.5180      1.195     -0.434      0.668      -2.958       1.922
# hbp            0.0882      0.507      0.174      0.863      -0.946       1.123
# xfip         -11.3799      7.080     -1.607      0.118     -25.839       3.079
# gbpercen      32.5159     62.514      0.520      0.607     -95.154     160.186
# fbpercen     139.4768     81.368      1.714      0.097     -26.699     305.652
# ==============================================================================
# Omnibus:                        2.598   Durbin-Watson:                   1.889
# Prob(Omnibus):                  0.273   Jarque-Bera (JB):                1.966
# Skew:                          -0.210   Prob(JB):                        0.374
# Kurtosis:                       3.654   Cond. No.                     4.57e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.57e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#    razz_value               name  era_x  whip_x  bbpercen_x  w_x  l_x  so_x  \
# 0        42.7   Justin Verlander   3.04    1.00       0.063   16    9   254
# 1        40.9        Gerrit Cole   3.88    1.44       0.071    7   10    98
# 2        26.2  Stephen Strasburg   3.60    1.10       0.074   15    4   183
# 3        25.2       Jacob deGrom   3.04    1.20       0.060    7    8   143
# 4        24.8       Zack Greinke   4.37    1.27       0.061   13    7   134
# 5        20.1    Clayton Kershaw   1.69    0.72       0.020   12    4   172
# 6        19.8       Max Scherzer   2.96    0.97       0.062   20    7   284
# 7        17.9     Patrick Corbin   5.15    1.56       0.094    5   13   131
# 8        16.1         Sonny Gray   5.69    1.50       0.081    5   11    94
# 9        14.8      Roberto Osuna   2.68    0.93       0.049    4    3    82
#
#    sv_x  hld_x  ...  babip  xfip  gbpercen  fbpercen  predictions  \
# 0     0      0  ...  0.272  3.03     0.291     0.514    42.014962
# 1     0      0  ...  0.286  3.04     0.360     0.427    30.331326
# 2     0      0  ...  0.309  3.28     0.436     0.341    14.740761
# 3     0      0  ...  0.281  2.60     0.464     0.316    21.825951
# 4     0      0  ...  0.272  3.44     0.451     0.319    16.698926
# 5     0      0  ...  0.273  3.19     0.479     0.296    19.960479
# 6     0      0  ...  0.265  3.06     0.343     0.476    20.344259
# 7     1      2  ...  0.302  2.61     0.485     0.272    19.961573
# 8     0      0  ...  0.326  4.10     0.500     0.271     1.728345
# 9    36      0  ...  0.294  3.72     0.413     0.339    12.907797
#
#    predictions_ranks  razz_ranks    avg  adp_ranks  rating_diff
# 0                1.0         1.0   21.2        4.0          3.0
# 1                2.0         2.0   26.8        7.0          5.0
# 2                9.0         3.0   58.0       16.0          7.0
# 3                3.0         4.0   10.4        2.0         -1.0
# 4                7.0         5.0   56.0       15.0          8.0
# 5                6.0         6.0   55.4       14.0          8.0
# 6                4.0         7.0    4.8        1.0         -3.0
# 7                5.0         8.0   45.6       12.0          7.0
# 8               42.0         9.0  271.6       49.0          7.0
# 9               12.0        10.5   78.0       19.0          7.0
#
# [10 rows x 68 columns]

# %%
import sklearn.metrics as metrics
def regression_results(y_true, y_pred):
    # Regression metrics
    explained_variance=metrics.explained_variance_score(y_true, y_pred)
    mean_absolute_error=metrics.mean_absolute_error(y_true, y_pred) 
    mse=metrics.mean_squared_error(y_true, y_pred) 
    mean_squared_log_error=metrics.mean_squared_log_error(y_true, y_pred)
    median_absolute_error=metrics.median_absolute_error(y_true, y_pred)
    r2=metrics.r2_score(y_true, y_pred)
    print('explained_variance: ', round(explained_variance,4))    
    print('mean_squared_log_error: ', round(mean_squared_log_error,4))
    print('r2: ', round(r2,4))
    print('MAE: ', round(mean_absolute_error,4))
    print('MSE: ', round(mse,4))
    print('RMSE: ', round(np.sqrt(mse),4))

regression_results((y+100),predictions+100)
# Out:
# explained_variance:  0.8178
# mean_squared_log_error:  0.0028
# r2:  0.8178
# MAE:  3.8566
# MSE:  28.8636
# RMSE:  5.3725

# %%
X  = RazzSeason['predictions_ranks']
y= RazzSeason['razz_value']

x_min = np.array([[X.max()]])
x_max = np.array([[X.min()]])

y_min = [hitters_ranked['razz_value'].min()]
y_max = [hitters_ranked['razz_value'].max()]
    
plt.scatter(X, y, c='blue')
plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='red')
plt.xlabel("Predicted Rank")
plt.ylabel("Razz Value")
plt.savefig('2019Predict_Razz_Pitchers.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-c8b8969bec3e> in <module>
#       5 x_max = np.array([[X.min()]])
#       6
# ----> 7 y_min = [hitters_ranked['razz_value'].min()]
#       8 y_max = [hitters_ranked['razz_value'].max()]
#       9
#
# NameError: name 'hitters_ranked' is not defined

# %%
# Top Ten by ADP
RazzSeason = RazzSeason.sort_values(by=['avg'], ascending=True)
RazzSeason.head(10)
# Out:
#     razz_value              name  era_x  whip_x  bbpercen_x  w_x  l_x  so_x  \
# 6         19.8      Max Scherzer   2.96    0.97       0.062   20    7   284
# 3         25.2      Jacob deGrom   3.04    1.20       0.060    7    8   143
# 28         6.6        Chris Sale   3.34    1.04       0.050   17   10   233
# 0         42.7  Justin Verlander   3.04    1.00       0.063   16    9   254
# 70       -14.1      Corey Kluber   3.14    1.06       0.066   18    9   227
# 15        10.7        Aaron Nola   4.78    1.31       0.060    6    9   121
# 1         40.9       Gerrit Cole   3.88    1.44       0.071    7   10    98
# 42        -0.9       Blake Snell   3.54    1.62       0.127    6    8    98
# 18         9.1      Trevor Bauer   4.26    1.31       0.086   12    8   168
# 29         6.0  Noah Syndergaard   2.60    1.15       0.058   14    9   218
#
#     sv_x  hld_x  ...  babip  xfip  gbpercen  fbpercen  predictions  \
# 6      0      0  ...  0.265  3.06     0.343     0.476    20.344259
# 3      0      0  ...  0.281  2.60     0.464     0.316    21.825951
# 28     0      0  ...  0.283  2.31     0.442     0.362    12.480642
# 0      0      0  ...  0.272  3.03     0.291     0.514    42.014962
# 70     0      0  ...  0.276  3.08     0.444     0.333   -11.591787
# 15     0      0  ...  0.251  3.21     0.506     0.303     3.313917
# 1      0      0  ...  0.286  3.04     0.360     0.427    30.331326
# 42     0      0  ...  0.241  3.16     0.447     0.364     5.100790
# 18     0      0  ...  0.297  3.14     0.445     0.344     8.101087
# 29     0      1  ...  0.320  3.29     0.490     0.267     7.533347
#
#     predictions_ranks  razz_ranks   avg  adp_ranks  rating_diff
# 6                 4.0         7.0   4.8        1.0         -3.0
# 3                 3.0         4.0  10.4        2.0         -1.0
# 28               14.0        29.0  12.4        3.0        -11.0
# 0                 1.0         1.0  21.2        4.0          3.0
# 70               70.0        71.0  22.8        5.0        -65.0
# 15               37.0        16.0  24.6        6.0        -31.0
# 1                 2.0         2.0  26.8        7.0          5.0
# 42               30.0        43.0  27.8        8.0        -22.0
# 18               20.0        19.0  31.0        9.0        -11.0
# 29               26.0        30.0  34.8       10.0        -16.0
#
# [10 rows x 68 columns]

# %%
# Our Top Ten
RazzSeason = RazzSeason.sort_values(by=['predictions_ranks'], ascending=True)
RazzSeason.head(10)
# Out:
#     razz_value               name  era_x  whip_x  bbpercen_x  w_x  l_x  so_x  \
# 0         42.7   Justin Verlander   3.04    1.00       0.063   16    9   254
# 1         40.9        Gerrit Cole   3.88    1.44       0.071    7   10    98
# 3         25.2       Jacob deGrom   3.04    1.20       0.060    7    8   143
# 6         19.8       Max Scherzer   2.96    0.97       0.062   20    7   284
# 7         17.9     Patrick Corbin   5.15    1.56       0.094    5   13   131
# 5         20.1    Clayton Kershaw   1.69    0.72       0.020   12    4   172
# 4         24.8       Zack Greinke   4.37    1.27       0.061   13    7   134
# 14        10.8       James Paxton   3.79    1.31       0.047    6    7   117
# 2         26.2  Stephen Strasburg   3.60    1.10       0.074   15    4   183
# 13        11.8      Kenley Jansen   1.83    0.67       0.044    3    2   104
#
#     sv_x  hld_x  ...  babip  xfip  gbpercen  fbpercen  predictions  \
# 0      0      0  ...  0.272  3.03     0.291     0.514    42.014962
# 1      0      0  ...  0.286  3.04     0.360     0.427    30.331326
# 3      0      0  ...  0.281  2.60     0.464     0.316    21.825951
# 6      0      0  ...  0.265  3.06     0.343     0.476    20.344259
# 7      1      2  ...  0.302  2.61     0.485     0.272    19.961573
# 5      0      0  ...  0.273  3.19     0.479     0.296    19.960479
# 4      0      0  ...  0.272  3.44     0.451     0.319    16.698926
# 14     0      0  ...  0.299  3.02     0.396     0.411    15.467445
# 2      0      0  ...  0.309  3.28     0.436     0.341    14.740761
# 13    47      0  ...  0.234  3.56     0.353     0.439    13.507697
#
#     predictions_ranks  razz_ranks   avg  adp_ranks  rating_diff
# 0                 1.0         1.0  21.2        4.0          3.0
# 1                 2.0         2.0  26.8        7.0          5.0
# 3                 3.0         4.0  10.4        2.0         -1.0
# 6                 4.0         7.0   4.8        1.0         -3.0
# 7                 5.0         8.0  45.6       12.0          7.0
# 5                 6.0         6.0  55.4       14.0          8.0
# 4                 7.0         5.0  56.0       15.0          8.0
# 14                8.0        15.0  49.6       13.0          5.0
# 2                 9.0         3.0  58.0       16.0          7.0
# 13               10.0        14.0  70.0       18.0          8.0
#
# [10 rows x 68 columns]

# %%
RazzSeason = RazzSeason.sort_values(by=['rating_diff'], ascending=True)
RazzSeason.head(10)
# Out:
#     razz_value             name  era_x  whip_x  bbpercen_x  w_x  l_x  so_x  \
# 70       -14.1     Corey Kluber   3.14    1.06       0.066   18    9   227
# 50        -3.4  Carlos Carrasco   3.32    1.15       0.057   11    8   150
# 64       -10.1       Wade Davis   1.87    1.13       0.091    2    1    47
# 46        -1.9      David Price   3.99    1.20       0.053   17    9   228
# 15        10.7       Aaron Nola   4.78    1.31       0.060    6    9   121
# 67       -11.4    Kevin Gausman   3.61    1.28       0.062    9   12   174
# 40         0.1       Jon Lester   2.44    1.02       0.065   19    5   197
# 34         2.6  Masahiro Tanaka   3.07    1.08       0.045   14    4   165
# 42        -0.9      Blake Snell   3.54    1.62       0.127    6    8    98
# 58        -7.0    Collin McHugh   4.34    1.41       0.068   13   10   177
#
#     sv_x  hld_x  ...  babip  xfip  gbpercen  fbpercen  predictions  \
# 70     0      0  ...  0.276  3.08     0.444     0.333   -11.591787
# 50     0      0  ...  0.315  2.90     0.468     0.320    -5.601281
# 64    27      0  ...  0.238  3.63     0.416     0.403    -9.919464
# 46     0      0  ...  0.274  3.95     0.401     0.393    -8.039441
# 15     0      0  ...  0.251  3.21     0.506     0.303     3.313917
# 67     0      0  ...  0.299  4.19     0.460     0.335   -13.635327
# 40     0      0  ...  0.290  4.43     0.377     0.364    -8.014068
# 34     0      0  ...  0.284  3.42     0.472     0.331    -1.225607
# 42     0      0  ...  0.241  3.16     0.447     0.364     5.100790
# 58     0      0  ...  0.248  3.26     0.346     0.438    -9.347666
#
#     predictions_ranks  razz_ranks    avg  adp_ranks  rating_diff
# 70               70.0        71.0   22.8        5.0        -65.0
# 50               57.0        50.5   35.4       11.0        -46.0
# 64               67.0        64.5  117.4       25.0        -42.0
# 46               61.0        47.0   85.8       20.0        -41.0
# 15               37.0        16.0   24.6        6.0        -31.0
# 67               73.0        68.0  217.2       43.0        -30.0
# 40               60.0        41.0  164.8       35.0        -25.0
# 34               48.0        35.0  117.2       24.0        -24.0
# 42               30.0        43.0   27.8        8.0        -22.0
# 58               66.0        58.5  217.8       44.0        -22.0
#
# [10 rows x 68 columns]

# %%
RazzSeason = RazzSeason.sort_values(by=['rating_diff'], ascending=False)
RazzSeason.head(10)
# Out:
#     razz_value               name  era_x  whip_x  bbpercen_x  w_x  l_x  so_x  \
# 27         6.7        Ian Kennedy   3.68    1.22       0.081   11   11   184
# 53        -4.9    Vince Velasquez   4.12    1.33       0.082    8    6   152
# 11        12.8      Jake Odorizzi   3.69    1.19       0.070   10    6   166
# 23         8.6    Jeff Samardzija   3.81    1.20       0.065   12   11   167
# 20         8.8        Alex Colome   1.91    1.02       0.066    2    4    71
# 30         5.4     Marcus Stroman   4.37    1.29       0.063    9   10   166
# 55        -6.2      Hector Rondon   3.53    0.98       0.040    2    3    58
# 33         2.7    Adam Wainwright   4.62    1.40       0.070   13    9   161
# 16         9.5        Kenta Maeda   3.48    1.14       0.070   16   11   179
# 10        14.8  Eduardo Rodriguez   4.71    1.30       0.087    3    7   100
#
#     sv_x  hld_x  ...  babip  xfip  gbpercen  fbpercen  predictions  \
# 27     0      0  ...  0.298  4.64     0.299     0.438     6.015878
# 53     0      0  ...  0.316  4.12     0.377     0.408     7.642626
# 11     0      0  ...  0.290  4.87     0.284     0.488     7.592002
# 23     0      0  ...  0.287  6.18     0.299     0.465     6.789913
# 20    37      1  ...  0.291  3.44     0.462     0.296     9.991277
# 30     0      0  ...  0.326  3.84     0.621     0.200     7.076798
# 55    18      7  ...  0.340  3.39     0.457     0.327    -2.328186
# 33     0      0  ...  0.310  4.26     0.487     0.333     0.187143
# 16     0      0  ...  0.321  3.37     0.402     0.353    10.131385
# 10     0      0  ...  0.301  3.90     0.387     0.412    13.374448
#
#     predictions_ranks  razz_ranks    avg  adp_ranks  rating_diff
# 27               29.0        28.0  707.7       77.0         48.0
# 53               23.0        54.0  359.0       57.0         34.0
# 11               25.0        12.0  366.3       59.0         34.0
# 23               28.0        24.0  379.7       61.0         33.0
# 20               16.0        21.5  211.2       42.0         26.0
# 30               27.0        31.0  282.4       51.0         24.0
# 55               51.0        56.0  585.5       74.0         23.0
# 33               45.0        34.0  471.3       68.0         23.0
# 16               15.0        17.0  176.2       38.0         23.0
# 10               11.0        10.5  150.8       34.0         23.0
#
# [10 rows x 68 columns]

# %%
years =['2012','2013','2014', '2015', '2016']
model = LinearRegression()
Hitters_Nineteen = hitters.loc[ (hitters['season']==2019)]
Hitters_Nineteen= Hitters_Nineteen[['name','avg']]
for year in years:
    SeasonOne = hitters.loc[ (hitters['season']==int(year))]
    SeasonTwo = hitters.loc[ (hitters['season']==(int(year)+1))]
    SeasonThree = hitters.loc[ (hitters['season']==(int(year)+2))]
    RazzSeason = hitters.loc[ (hitters['season']==(int(year)+3))]

    SeasonOne = SeasonOne[["name",'o_swingpercen','o_contactpercen','z_swingpercen','z_contactpercen','ops','r',
                          'rbi', 'hr','sb', 'pa', 'kpercen','bbpercen','iffbpercen']]
    SeasonTwo = SeasonTwo[["name",'o_swingpercen','o_contactpercen','z_swingpercen','z_contactpercen','ops','r',
                          'rbi', 'hr','sb', 'pa', 'kpercen','bbpercen','iffbpercen']]
    SeasonThree = SeasonThree[["name",'o_swingpercen','o_contactpercen','z_swingpercen','z_contactpercen','ops','r',
                          'rbi', 'hr','sb', 'pa', 'kpercen','bbpercen','iffbpercen']]
    RazzSeason = RazzSeason[['razz_value','name']].dropna()
    RazzSeason = RazzSeason.merge(SeasonOne , on='name')
    RazzSeason = RazzSeason.merge(SeasonTwo , on='name')
    RazzSeason = RazzSeason.merge(SeasonThree , on='name')
    
col = [RazzSeason.columns]
for col in col:
    print(col)
# Out:
# Index(['razz_value', 'name', 'o_swingpercen_x', 'o_contactpercen_x',
#        'z_swingpercen_x', 'z_contactpercen_x', 'ops_x', 'r_x', 'rbi_x', 'hr_x',
#        'sb_x', 'pa_x', 'kpercen_x', 'bbpercen_x', 'iffbpercen_x',
#        'o_swingpercen_y', 'o_contactpercen_y', 'z_swingpercen_y',
#        'z_contactpercen_y', 'ops_y', 'r_y', 'rbi_y', 'hr_y', 'sb_y', 'pa_y',
#        'kpercen_y', 'bbpercen_y', 'iffbpercen_y', 'o_swingpercen',
#        'o_contactpercen', 'z_swingpercen', 'z_contactpercen', 'ops', 'r',
#        'rbi', 'hr', 'sb', 'pa', 'kpercen', 'bbpercen', 'iffbpercen'],
#       dtype='object')

# %%
years =['2012','2013','2014', '2015', '2016']
model = LinearRegression()
Hitters_Nineteen = hitters.loc[ (hitters['season']==2019)]
Hitters_Nineteen= Hitters_Nineteen[['name','avg']]
for year in years:
    SeasonOne = hitters.loc[ (hitters['season']==int(year))]
    SeasonTwo = hitters.loc[ (hitters['season']==(int(year)+1))]
    SeasonThree = hitters.loc[ (hitters['season']==(int(year)+2))]
    RazzSeason = hitters.loc[ (hitters['season']==(int(year)+3))]

    SeasonOne = SeasonOne[["name", 'age','o_swingpercen','o_contactpercen','z_swingpercen','z_contactpercen','ops','r',
                          'rbi', 'hr','sb', 'pa', 'kpercen','bbpercen','iffbpercen']]
    SeasonTwo = SeasonTwo[["name",'age','o_swingpercen','o_contactpercen','z_swingpercen','z_contactpercen','ops','r',
                          'rbi', 'hr','sb', 'pa', 'kpercen','bbpercen','iffbpercen']]
    SeasonThree = SeasonThree[["name",'age','o_swingpercen','o_contactpercen','z_swingpercen','z_contactpercen','ops','r',
                          'rbi', 'hr','sb', 'pa', 'kpercen','bbpercen','iffbpercen']]
    RazzSeason = RazzSeason[['razz_value','name']].dropna()
    RazzSeason = RazzSeason.merge(SeasonOne , on='name')
    RazzSeason = RazzSeason.merge(SeasonTwo , on='name')
    RazzSeason = RazzSeason.merge(SeasonThree , on='name')
    X= RazzSeason[['age_y','o_swingpercen_x', 'o_contactpercen_x',
        'ops_x', 'rbi_x', 'hr_x',
       'sb_x', 'pa_x', 'kpercen_x', 'bbpercen_x', 'iffbpercen_x',
       'o_swingpercen_y', 'o_contactpercen_y', 'z_swingpercen_y',
       'z_contactpercen_y', 'ops_y', 'r_y', 'rbi_y', 'hr_y', 'sb_y', 'pa_y',
       'kpercen_y', 'bbpercen_y',  'ops',
       'rbi', 'hr', 'sb',  'bbpercen', 'iffbpercen']]
    y= RazzSeason[['razz_value']].to_numpy()
    
    

    # Fitting our model with all of our features in X
    model.fit(X, y)

score = model.score(X, y)
print(f"R2 Score: {score}")
print(f" coef {model.coef_}")
print(f" int {model.intercept_}")
predictions = model.predict(X)
    # Plot Residuals
plt.scatter(predictions, predictions - y)
plt.hlines(y=0, xmin=predictions.min(), xmax=predictions.max())
plt.show()

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
    
predictions = model.predict(X)
RazzSeason['predictions']= predictions
RazzSeason['predictions_ranks'] =RazzSeason['predictions'].rank(ascending=False)
RazzSeason['razz_ranks'] =RazzSeason['razz_value'].rank(ascending=False)

RazzSeason= RazzSeason.merge(Hitters_Nineteen, on='name')
RazzSeason['adp_ranks'] = RazzSeason['avg'].rank(ascending=True)
RazzSeason['rating_diff']= ( RazzSeason['adp_ranks'] - RazzSeason['predictions_ranks'])
hitters_ranked = RazzSeason
hitters_ranked.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-23d7589f4c45> in <module>
#       1 years =['2012','2013','2014', '2015', '2016']
# ----> 2 model = LinearRegression()
#       3 Hitters_Nineteen = hitters.loc[ (hitters['season']==2019)]
#       4 Hitters_Nineteen= Hitters_Nineteen[['name','avg']]
#       5 for year in years:
#
# NameError: name 'LinearRegression' is not defined

# %%
X  = hitters_ranked['predictions_ranks']
y= hitters_ranked['razz_value']

x_min = np.array([[X.max()]])
x_max = np.array([[X.min()]])

y_min = [hitters_ranked['razz_value'].min()]
y_max = [hitters_ranked['razz_value'].max()]
    
plt.scatter(X, y, c='blue')
plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='red')
plt.xlabel("Predicted Rank")
plt.ylabel("Razz Value")
plt.savefig('2019Predict_Razz.png')
plt.show()

# %%
# Our Top Ten
hitters_ranked = hitters_ranked.sort_values(by=['predictions_ranks'], ascending=True)
hitters_ranked.head(10)
# Out:
#     razz_value              name  age_x  o_swingpercen_x  o_contactpercen_x  \
# 4         31.1        Mike Trout     24            0.230              0.706
# 0         39.9  Christian Yelich     24            0.229              0.540
# 8         29.0      Mookie Betts     23            0.255              0.715
# 5         26.0      Bryce Harper     23            0.270              0.663
# 24        16.8  Paul Goldschmidt     28            0.230              0.696
# 1         28.5      Trevor Story     23            0.279              0.562
# 15        24.4     J.D. Martinez     28            0.332              0.524
# 12        26.6   Xander Bogaerts     23            0.338              0.684
# 9         29.7     Nolan Arenado     25            0.341              0.708
# 20        23.5   George Springer     26            0.272              0.618
#
#     z_swingpercen_x  z_contactpercen_x  ops_x  r_x  rbi_x  ...   pa  kpercen  \
# 4             0.603              0.870  0.991  123    100  ...  608    0.204
# 0             0.643              0.884  0.859   78     98  ...  651    0.207
# 8             0.584              0.948  0.897  122    113  ...  614    0.148
# 5             0.681              0.874  0.814   84     86  ...  695    0.243
# 24            0.607              0.844  0.899  106     95  ...  690    0.251
# 1             0.667              0.807  0.909   67     72  ...  656    0.256
# 15            0.771              0.845  0.908   69     68  ...  649    0.225
# 12            0.591              0.907  0.802  115     89  ...  580    0.176
# 9             0.686              0.901  0.932  116    133  ...  673    0.181
# 20            0.741              0.797  0.815  116     82  ...  620    0.197
#
#     bbpercen  iffbpercen  predictions  predictions_ranks  razz_ranks   avg  \
# 4      0.201       0.094    32.694236                1.0         3.0   1.0
# 0      0.104       0.049    31.925718                2.0         1.0   7.8
# 8      0.132       0.092    30.812394                3.0         6.0   2.0
# 5      0.187       0.034    29.371778                4.0        11.0  16.4
# 24     0.130       0.118    29.161192                5.0        30.5  20.2
# 1      0.072       0.102    28.503497                6.0         7.0  20.2
# 15     0.106       0.027    27.134805                7.0        15.5   4.8
# 12     0.095       0.108    25.134002                8.0        10.0  44.6
# 9      0.108       0.120    23.253544                9.0         5.0   5.8
# 20     0.103       0.082    23.086430               10.0        17.0  48.8
#
#     adp_ranks  rating_diff
# 4         1.0          0.0
# 0         5.0          3.0
# 8         2.0         -1.0
# 5         9.0          5.0
# 24       12.5          7.5
# 1        12.5          6.5
# 15        3.0         -4.0
# 12       21.5         13.5
# 9         4.0         -5.0
# 20       24.0         14.0
#
# [10 rows x 50 columns]

# %%
# Top Ten by ADP
hitters_ranked = hitters_ranked.sort_values(by=['avg'], ascending=True)
hitters_ranked.head(10)
# Out:
#     razz_value              name  age_x  o_swingpercen_x  o_contactpercen_x  \
# 4         31.1        Mike Trout     24            0.230              0.706
# 8         29.0      Mookie Betts     23            0.255              0.715
# 15        24.4     J.D. Martinez     28            0.332              0.524
# 9         29.7     Nolan Arenado     25            0.341              0.708
# 0         39.9  Christian Yelich     24            0.229              0.540
# 21        21.6       Trea Turner     23            0.326              0.592
# 10        22.6  Francisco Lindor     22            0.303              0.714
# 38        17.9       Jose Altuve     26            0.327              0.777
# 5         26.0      Bryce Harper     23            0.270              0.663
# 28        16.2       Javier Baez     23            0.429              0.624
#
#     z_swingpercen_x  z_contactpercen_x  ops_x  r_x  rbi_x  ...   pa  kpercen  \
# 4             0.603              0.870  0.991  123    100  ...  608    0.204
# 8             0.584              0.948  0.897  122    113  ...  614    0.148
# 15            0.771              0.845  0.908   69     68  ...  649    0.225
# 9             0.686              0.901  0.932  116    133  ...  673    0.181
# 0             0.643              0.884  0.859   78     98  ...  651    0.207
# 21            0.655              0.889  0.937   53     40  ...  740    0.178
# 10            0.697              0.906  0.794   99     78  ...  745    0.144
# 38            0.712              0.913  0.928  108     96  ...  599    0.132
# 5             0.681              0.874  0.814   84     86  ...  695    0.243
# 28            0.679              0.823  0.737   50     59  ...  645    0.259
#
#     bbpercen  iffbpercen  predictions  predictions_ranks  razz_ranks   avg  \
# 4      0.201       0.094    32.694236                1.0         3.0   1.0
# 8      0.132       0.092    30.812394                3.0         6.0   2.0
# 15     0.106       0.027    27.134805                7.0        15.5   4.8
# 9      0.108       0.120    23.253544                9.0         5.0   5.8
# 0      0.104       0.049    31.925718                2.0         1.0   7.8
# 21     0.093       0.128    20.549866               13.0        21.0   8.4
# 10     0.094       0.105    16.342776               21.0        19.0  12.6
# 38     0.092       0.059    14.355347               28.0        25.5  13.2
# 5      0.187       0.034    29.371778                4.0        11.0  16.4
# 28     0.045       0.114    22.725776               11.0        33.0  18.0
#
#     adp_ranks  rating_diff
# 4         1.0          0.0
# 8         2.0         -1.0
# 15        3.0         -4.0
# 9         4.0         -5.0
# 0         5.0          3.0
# 21        6.0         -7.0
# 10        7.0        -14.0
# 38        8.0        -20.0
# 5         9.0          5.0
# 28       10.5         -0.5
#
# [10 rows x 50 columns]

# %%
hitters_ranked = hitters_ranked.sort_values(by=['rating_diff'], ascending=False)
hitters_ranked.head(10)
# Out:
#     razz_value             name  age_x  o_swingpercen_x  o_contactpercen_x  \
# 54         6.1    Jason Heyward     26            0.262              0.751
# 46        10.8     Joc Pederson     24            0.274              0.607
# 83         7.5   Howie Kendrick     32            0.305              0.650
# 11        25.6      Jorge Soler     24            0.255              0.468
# 78         1.2     Jason Kipnis     29            0.275              0.669
# 56         8.8      Miguel Sano     23            0.237              0.417
# 68         2.6  Kevin Kiermaier     26            0.279              0.688
# 89         3.4     Hunter Pence     33            0.315              0.552
# 18        27.4      DJ LeMahieu     27            0.239              0.794
# 43        12.0       Adam Eaton     27            0.311              0.754
#
#     z_swingpercen_x  z_contactpercen_x  ops_x  r_x  rbi_x  ...   pa  kpercen  \
# 54            0.600              0.910  0.631   61     49  ...  489    0.123
# 46            0.617              0.842  0.847   64     68  ...  443    0.192
# 83            0.688              0.889  0.691   65     40  ...  160    0.181
# 11            0.715              0.788  0.769   37     31  ...  257    0.268
# 78            0.620              0.900  0.811   91     82  ...  601    0.186
# 56            0.629              0.773  0.781   57     66  ...  299    0.385
# 68            0.661              0.842  0.741   55     37  ...  367    0.248
# 89            0.651              0.817  0.808   58     57  ...  248    0.238
# 18            0.609              0.947  0.911  104     66  ...  581    0.141
# 43            0.665              0.901  0.790   91     59  ...  370    0.173
#
#     bbpercen  iffbpercen  predictions  predictions_ranks  razz_ranks    avg  \
# 54     0.086       0.185    10.966224               41.0        59.0  426.7
# 46     0.090       0.103    16.090851               22.0        44.0  316.4
# 83     0.031       0.086     8.663688               52.0        55.0  587.3
# 11     0.109       0.132    11.920192               34.0        12.0  319.2
# 78     0.100       0.102    10.452105               45.0        79.0  342.8
# 56     0.104       0.079    11.583781               37.0        53.0  273.8
# 68     0.068       0.151     9.301641               50.0        70.0  322.2
# 89     0.044       0.192     4.363043               72.0        68.0  540.5
# 18     0.064       0.030    13.602236               31.0         9.0  220.0
# 43     0.103       0.123    14.256214               29.0        40.0  197.4
#
#     adp_ranks  rating_diff
# 54      101.0         60.0
# 46       81.0         59.0
# 83      110.0         58.0
# 11       82.0         48.0
# 78       91.0         46.0
# 56       77.0         40.0
# 68       86.0         36.0
# 89      108.0         36.0
# 18       65.0         34.0
# 43       63.0         34.0
#
# [10 rows x 50 columns]

# %%
hitters_ranked = hitters_ranked.sort_values(by=['rating_diff'], ascending=True)
hitters_ranked.head(10)
# Out:
#      razz_value              name  age_x  o_swingpercen_x  o_contactpercen_x  \
# 49         -2.3       Khris Davis     28            0.313              0.515
# 69          0.8        Joey Votto     32            0.208              0.758
# 99         -1.7      Buster Posey     29            0.293              0.781
# 41         11.2      Rougned Odor     22            0.418              0.650
# 84          6.2     Yadier Molina     33            0.360              0.814
# 53          6.9      Corey Seager     22            0.322              0.594
# 102        -7.0     Robinson Cano     33            0.373              0.712
# 105       -13.2       Jose Peraza     22            0.367              0.767
# 74         -4.3    Miguel Cabrera     33            0.329              0.683
# 100        -6.7  Stephen Piscotty     25            0.331              0.607
#
#      z_swingpercen_x  z_contactpercen_x  ops_x  r_x  rbi_x  ...   pa  kpercen  \
# 49             0.767              0.762  0.831   85    102  ...  654    0.268
# 69             0.686              0.855  0.985  101     97  ...  623    0.162
# 99             0.681              0.915  0.796   82     80  ...  448    0.118
# 41             0.713              0.882  0.798   89     88  ...  535    0.237
# 84             0.727              0.896  0.787   56     58  ...  503    0.131
# 53             0.790              0.884  0.877  105     72  ...  115    0.148
# 102            0.714              0.932  0.882  107    103  ...  348    0.135
# 105            0.686              0.939  0.762   25     25  ...  683    0.110
# 74             0.729              0.858  0.956   92    108  ...  157    0.172
# 100            0.754              0.845  0.800   86     85  ...  605    0.188
#
#      bbpercen  iffbpercen  predictions  predictions_ranks  razz_ranks    avg  \
# 49      0.090       0.070     3.097437               83.0        90.0   41.6
# 69      0.173       0.000     0.821778               88.0        81.0   52.4
# 99      0.100       0.028    -5.440142              106.0        88.0  125.8
# 41      0.080       0.115    -4.609122              105.0        43.0  133.6
# 84      0.058       0.075    -3.267353              100.0        58.0  133.6
# 53      0.096       0.000     3.937308               76.0        56.0   68.8
# 102     0.092       0.064     2.626510               85.0       104.0  103.4
# 105     0.042       0.077     1.824180               86.0       110.0  109.8
# 74      0.140       0.091    -2.543773               96.0        95.0  152.4
# 100     0.069       0.049     0.034325               92.0       103.0  153.0
#
#      adp_ranks  rating_diff
# 49        20.0        -63.0
# 69        25.0        -63.0
# 99        45.0        -61.0
# 41        47.5        -57.5
# 84        47.5        -52.5
# 53        31.0        -45.0
# 102       40.0        -45.0
# 105       42.0        -44.0
# 74        53.0        -43.0
# 100       55.0        -37.0
#
# [10 rows x 50 columns]

# %%
import sklearn.metrics as metrics
def regression_results(y_true, y_pred):
    # Regression metrics
    explained_variance=metrics.explained_variance_score(y_true, y_pred)
    mean_absolute_error=metrics.mean_absolute_error(y_true, y_pred) 
    mse=metrics.mean_squared_error(y_true, y_pred) 
    mean_squared_log_error=metrics.mean_squared_log_error(y_true, y_pred)
    median_absolute_error=metrics.median_absolute_error(y_true, y_pred)
    r2=metrics.r2_score(y_true, y_pred)
    print('explained_variance: ', round(explained_variance,4))    
    print('mean_squared_log_error: ', round(mean_squared_log_error,4))
    print('r2: ', round(r2,4))
    print('MAE: ', round(mean_absolute_error,4))
    print('MSE: ', round(mse,4))
    print('RMSE: ', round(np.sqrt(mse),4))

regression_results((y+100),predictions+100)
# Out:
# explained_variance:  0.6159
# mean_squared_log_error:  0.005
# r2:  0.6159
# MAE:  6.0653
# MSE:  56.3608
# RMSE:  7.5074

# %% [markdown]
# # Top 30 Models

# %%
### 3 years of data starting in 2018 to get X values

year = '2018'
SeasonOne = hitters.loc[ (hitters['season']==int(year))]
SeasonTwo = hitters.loc[ (hitters['season']==(int(year)+1))]
RazzSeason = hitters.loc[ (hitters['season']==(int(year)+2))]

SeasonOne = SeasonOne[["name", 'age','o_swingpercen','o_contactpercen','z_swingpercen','z_contactpercen','ops','r',
                      'rbi', 'hr','sb', 'pa', 'kpercen','bbpercen','iffbpercen']]
SeasonTwo = SeasonTwo[["name",'age','o_swingpercen','o_contactpercen','z_swingpercen','z_contactpercen','ops','r',
                      'rbi', 'hr','sb', 'pa', 'kpercen','bbpercen','iffbpercen']]
SeasonThree = SeasonThree[["name",'age','o_swingpercen','o_contactpercen','z_swingpercen','z_contactpercen','ops','r',
                      'rbi', 'hr','sb', 'pa', 'kpercen','bbpercen','iffbpercen']]

RazzSeason = RazzSeason[['name']]

RazzSeason = RazzSeason.dropna()

RazzSeason = RazzSeason.merge(SeasonOne , on='name')
RazzSeason = RazzSeason.merge(SeasonTwo , on='name')
RazzSeason = RazzSeason.merge(SeasonThree , on='name')
X_test= RazzSeason[['age_y','o_swingpercen_x', 'o_contactpercen_x',
    'ops_x', 'rbi_x', 'hr_x',
   'sb_x', 'pa_x', 'kpercen_x', 'bbpercen_x', 'iffbpercen_x',
   'o_swingpercen_y', 'o_contactpercen_y', 'z_swingpercen_y',
   'z_contactpercen_y', 'ops_y', 'r_y', 'rbi_y', 'hr_y', 'sb_y', 'pa_y',
   'kpercen_y', 'bbpercen_y',  'ops',
   'rbi', 'hr', 'sb',  'bbpercen', 'iffbpercen']]

# %% [markdown]
# # 3 year model

# %%
### Top 30 Hitters 3-year model
Twenty_One_Prediction = model.predict(X_test)
RazzSeason['predicted_val'] = Twenty_One_Prediction

RazzSeason['predictions_ranks'] =RazzSeason['predicted_val'].rank(ascending=False)
RazzSeason =RazzSeason.sort_values(by=['predictions_ranks'], ascending=True)
RazzSeason.head(30)
# Out:
#                  name  age_x  o_swingpercen_x  o_contactpercen_x  \
# 130       Aaron Judge     26            0.251              0.441
# 87      J.D. Martinez     30            0.332              0.589
# 93      Jorge Polanco     24            0.252              0.714
# 126      Alex Bregman     24            0.200              0.791
# 141   Marwin Gonzalez     29            0.319              0.650
# 120     Jose Iglesias     28            0.397              0.791
# 4        Mookie Betts     25            0.198              0.706
# 12         Mike Trout     26            0.218              0.690
# 5         Trea Turner     25            0.266              0.677
# 44   Christian Yelich     26            0.277              0.622
# 19    Xander Bogaerts     25            0.301              0.658
# 51           Ian Happ     23            0.247              0.504
# 190       Jose Peraza     24            0.352              0.761
# 122   Eduardo Escobar     29            0.393              0.690
# 3        Jose Ramirez     25            0.223              0.794
# 92       Byron Buxton     24            0.394              0.588
# 150     Shin-Soo Choo     35            0.239              0.598
# 131        Ryan Braun     34            0.363              0.685
# 104         Josh Bell     25            0.267              0.654
# 129       Ketel Marte     24            0.281              0.775
# 50       Chris Taylor     27            0.258              0.534
# 73        Jean Segura     28            0.346              0.783
# 183     Johan Camargo     24            0.360              0.667
# 148    Hunter Renfroe     26            0.326              0.603
# 123       Jorge Soler     26            0.288              0.422
# 61        Eric Hosmer     28            0.331              0.584
# 47     Brian Anderson     25            0.281              0.650
# 38   Charlie Blackmon     31            0.318              0.699
# 62    Robbie Grossman     28            0.186              0.613
# 41         Matt Olson     24            0.251              0.672
#
#      z_swingpercen_x  z_contactpercen_x  ops_x  r_x  rbi_x  hr_x  ...    r  \
# 130            0.638              0.791  0.919   77     67    27  ...   77
# 87             0.766              0.834  1.031  111    130    43  ...  111
# 93             0.628              0.925  0.773   38     42     6  ...   38
# 126            0.605              0.928  0.926  105    103    31  ...  105
# 141            0.599              0.863  0.733   61     68    16  ...   61
# 120            0.619              0.939  0.699   43     48     5  ...   43
# 4              0.570              0.930  1.078  129     80    32  ...  129
# 12             0.591              0.917  1.088  101     79    39  ...  101
# 5              0.650              0.884  0.760  103     73    19  ...  103
# 44             0.646              0.881  1.000  118    110    36  ...  118
# 19             0.613              0.893  0.883   72    103    23  ...   72
# 51             0.683              0.702  0.761   56     44    15  ...   56
# 190            0.675              0.956  0.742   85     58    14  ...   85
# 122            0.728              0.856  0.824   75     84    23  ...   75
# 3              0.623              0.921  0.939  110    105    39  ...  110
# 92             0.730              0.829  0.383    8      4     0  ...    8
# 150            0.624              0.821  0.810   83     62    21  ...   83
# 131            0.709              0.871  0.782   59     64    20  ...   59
# 104            0.678              0.845  0.768   74     62    12  ...   74
# 129            0.684              0.904  0.768   68     59    14  ...   68
# 50             0.723              0.785  0.775   85     63    17  ...   85
# 73             0.660              0.951  0.755   91     63    10  ...   91
# 183            0.697              0.818  0.806   63     76    19  ...   63
# 148            0.672              0.784  0.805   53     68    26  ...   53
# 123            0.680              0.804  0.820   27     28     9  ...   27
# 61             0.707              0.857  0.720   72     69    18  ...   72
# 47             0.686              0.849  0.757   87     65    11  ...   87
# 38             0.666              0.893  0.860  119     70    29  ...  119
# 62             0.637              0.938  0.751   50     48     5  ...   50
# 41             0.696              0.777  0.788   85     84    29  ...   85
#
#      rbi  hr  sb   pa  kpercen  bbpercen  iffbpercen  predicted_val  \
# 130   67  27   6  498    0.305     0.153       0.054      50.499456
# 87   130  43   6  649    0.225     0.106       0.027      42.534956
# 93    42   6   7  333    0.186     0.075       0.112      34.061692
# 126  103  31  10  705    0.121     0.136       0.126      32.514805
# 141   68  16   2  552    0.228     0.096       0.094      29.653375
# 120   48   5  15  464    0.101     0.041       0.194      29.625871
# 4     80  32  30  614    0.148     0.132       0.092      28.659486
# 12    79  39  24  608    0.204     0.201       0.094      28.659486
# 5     73  19  43  740    0.178     0.093       0.128      28.659486
# 44   110  36  22  651    0.207     0.104       0.049      28.659486
# 19   103  23   8  580    0.176     0.095       0.108      27.513594
# 51    44  15   8  462    0.361     0.152       0.060      26.986978
# 190   58  14  23  683    0.110     0.042       0.077      26.976975
# 122   84  23   2  631    0.200     0.082       0.057      26.506858
# 3    105  39  34  698    0.115     0.152       0.130      26.018689
# 92     4   0   5   94    0.298     0.032       0.150      25.552770
# 150   62  21   6  665    0.235     0.138       0.027      25.521285
# 131   64  20  11  447    0.190     0.076       0.055      25.231166
# 104   62  12   2  583    0.178     0.132       0.092      23.897550
# 129   59  14   6  580    0.136     0.093       0.109      23.828006
# 50    63  17   9  604    0.295     0.091       0.071      22.915644
# 73    63  10  20  632    0.109     0.051       0.139      22.559531
# 183   76  19   1  524    0.206     0.097       0.165      22.427792
# 148   68  26   2  441    0.247     0.068       0.156      22.290002
# 123   28   9   3  257    0.268     0.109       0.132      20.425958
# 61    69  18   7  677    0.210     0.092       0.097      19.611499
# 47    65  11   2  670    0.193     0.093       0.061      19.481008
# 38    70  29  12  696    0.193     0.085       0.049      19.210671
# 62    48   5   0  465    0.178     0.129       0.102      19.190336
# 41    84  29   2  660    0.247     0.106       0.150      19.133641
#
#      predictions_ranks
# 130                1.0
# 87                 2.0
# 93                 3.0
# 126                4.0
# 141                5.0
# 120                6.0
# 4                  8.5
# 12                 8.5
# 5                  8.5
# 44                 8.5
# 19                11.0
# 51                12.0
# 190               13.0
# 122               14.0
# 3                 15.0
# 92                16.0
# 150               17.0
# 131               18.0
# 104               19.0
# 129               20.0
# 50                21.0
# 73                22.0
# 183               23.0
# 148               24.0
# 123               25.0
# 61                26.0
# 47                27.0
# 38                28.0
# 62                29.0
# 41                30.0
#
# [30 rows x 45 columns]

# %% [markdown]
# # Two Year Model

# %%
## Two Year Model
years =['2012','2013','2014', '2015', '2016']
model = LinearRegression()
Hitters_Nineteen = hitters.loc[ (hitters['season']==2019)]
Hitters_Nineteen= Hitters_Nineteen[['name','avg']]
for year in years:
    SeasonOne = hitters.loc[ (hitters['season']==int(year))]
    SeasonTwo = hitters.loc[ (hitters['season']==(int(year)+1))]

    RazzSeason = hitters.loc[ (hitters['season']==(int(year)+2))]

    SeasonOne = SeasonOne[["name", 'age','o_swingpercen','o_contactpercen','z_swingpercen','z_contactpercen','ops','r',
                          'rbi', 'hr','sb', 'pa', 'kpercen','bbpercen','iffbpercen']]
    SeasonTwo = SeasonTwo[["name",'age','o_swingpercen','o_contactpercen','z_swingpercen','z_contactpercen','ops','r',
                          'rbi', 'hr','sb', 'pa', 'kpercen','bbpercen','iffbpercen']]
    RazzSeason = RazzSeason[['razz_value','name']].dropna()
    RazzSeason = RazzSeason.merge(SeasonOne , on='name')
    RazzSeason = RazzSeason.merge(SeasonTwo , on='name')
    X= RazzSeason[['age_y','o_swingpercen_x', 'o_contactpercen_x',
        'ops_x', 'rbi_x', 'hr_x',
       'sb_x', 'pa_x', 'kpercen_x', 'bbpercen_x', 'iffbpercen_x',
       'o_swingpercen_y', 'o_contactpercen_y', 'z_swingpercen_y',
       'z_contactpercen_y', 'ops_y', 'r_y', 'rbi_y', 'hr_y', 'sb_y', 'pa_y',
       'kpercen_y']]
    y= RazzSeason[['razz_value']].to_numpy()
    
    

    # Fitting our model with all of our features in X
    model.fit(X, y)

score = model.score(X, y)
print(f"R2 Score: {score}")
print(f" coef {model.coef_}")
print(f" int {model.intercept_}")
predictions = model.predict(X)
    # Plot Residuals
plt.scatter(predictions, predictions - y)
plt.hlines(y=0, xmin=predictions.min(), xmax=predictions.max())
plt.show()

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
    
predictions = model.predict(X)
RazzSeason['predictions']= predictions
RazzSeason['predictions_ranks'] =RazzSeason['predictions'].rank(ascending=False)
RazzSeason['razz_ranks'] =RazzSeason['razz_value'].rank(ascending=False)

RazzSeason= RazzSeason.merge(Hitters_Nineteen, on='name')
RazzSeason['adp_ranks'] = RazzSeason['avg'].rank(ascending=True)
RazzSeason['rating_diff']= ( RazzSeason['adp_ranks'] - RazzSeason['predictions_ranks'])
hitters_ranked = RazzSeason
hitters_ranked.head(10)
# Out:
# R2 Score: 0.41220917757751097
#  coef [[-8.27601280e-01 -4.56777280e+01 -1.31689020e+01  6.67135625e+01
#    9.67364557e-03 -3.12868383e-01 -4.98603234e-02  1.24563753e-02
#    6.09143384e+01 -6.60905980e+01 -9.94542916e+00  3.15239378e+01
#   -9.66674009e+00 -7.22661626e+00 -1.35291327e+01 -8.18571341e+00
#    1.02739352e-01  1.66677476e-01  1.43066390e-01  2.12874074e-01
#   -2.11309343e-02 -7.11049111e+01]]
#  int [16.83805336]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.412
# Model:                            OLS   Adj. R-squared:                  0.302
# Method:                 Least Squares   F-statistic:                     3.730
# Date:                Wed, 10 Mar 2021   Prob (F-statistic):           1.83e-06
# Time:                        13:39:26   Log-Likelihood:                -515.53
# No. Observations:                 140   AIC:                             1077.
# Df Residuals:                     117   BIC:                             1145.
# Df Model:                          22
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                16.8381     62.592      0.269      0.788    -107.122     140.798
# age_y                -0.8276      0.297     -2.784      0.006      -1.416      -0.239
# o_swingpercen_x     -45.6777     37.297     -1.225      0.223    -119.542      28.187
# o_contactpercen_x   -13.1689     28.340     -0.465      0.643     -69.295      42.957
# ops_x                66.7136     20.770      3.212      0.002      25.579     107.848
# rbi_x                 0.0097      0.100      0.097      0.923      -0.189       0.208
# hr_x                 -0.3129      0.224     -1.396      0.165      -0.757       0.131
# sb_x                 -0.0499      0.168     -0.297      0.767      -0.383       0.283
# pa_x                  0.0125      0.015      0.828      0.409      -0.017       0.042
# kpercen_x            60.9143     47.076      1.294      0.198     -32.318     154.146
# bbpercen_x          -66.0906     55.980     -1.181      0.240    -176.956      44.775
# iffbpercen_x         -9.9454     25.554     -0.389      0.698     -60.554      40.663
# o_swingpercen_y      31.5239     33.995      0.927      0.356     -35.802      98.850
# o_contactpercen_y    -9.6667     34.064     -0.284      0.777     -77.128      57.795
# z_swingpercen_y      -7.2266     26.465     -0.273      0.785     -59.639      45.186
# z_contactpercen_y   -13.5291     44.350     -0.305      0.761    -101.362      74.304
# ops_y                -8.1857     22.232     -0.368      0.713     -52.216      35.844
# r_y                   0.1027      0.137      0.752      0.453      -0.168       0.373
# rbi_y                 0.1667      0.102      1.641      0.104      -0.035       0.368
# hr_y                  0.1431      0.238      0.600      0.550      -0.329       0.615
# sb_y                  0.2129      0.206      1.035      0.303      -0.194       0.620
# pa_y                 -0.0211      0.023     -0.899      0.370      -0.068       0.025
# kpercen_y           -71.1049     53.638     -1.326      0.188    -177.332      35.122
# ==============================================================================
# Omnibus:                        3.070   Durbin-Watson:                   0.908
# Prob(Omnibus):                  0.215   Jarque-Bera (JB):                2.615
# Skew:                          -0.320   Prob(JB):                        0.270
# Kurtosis:                       3.196   Cond. No.                     7.97e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.97e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#    razz_value              name  age_x  o_swingpercen_x  o_contactpercen_x  \
# 0        35.7  Francisco Lindor     22            0.303              0.714
# 1        42.3  Christian Yelich     24            0.229              0.540
# 2        33.4      Trevor Story     23            0.279              0.562
# 3        42.4      Mookie Betts     23            0.255              0.715
# 4        32.5       Javier Baez     23            0.429              0.624
# 5        41.1     J.D. Martinez     28            0.332              0.524
# 6        33.7        Mike Trout     24            0.230              0.706
# 7        28.3     Manny Machado     23            0.323              0.665
# 8        27.4       Trea Turner     23            0.326              0.592
# 9        27.8       Khris Davis     28            0.313              0.515
#
#    z_swingpercen_x  z_contactpercen_x  ops_x  r_x  rbi_x  ...  pa_y  \
# 0            0.697              0.906  0.794   99     78  ...   723
# 1            0.643              0.884  0.859   78     98  ...   695
# 2            0.667              0.807  0.909   67     72  ...   555
# 3            0.584              0.948  0.897  122    113  ...   712
# 4            0.679              0.823  0.737   50     59  ...   508
# 5            0.771              0.845  0.908   69     68  ...   489
# 6            0.603              0.870  0.991  123    100  ...   507
# 7            0.723              0.873  0.876  105     96  ...   690
# 8            0.655              0.889  0.937   53     40  ...   447
# 9            0.767              0.762  0.831   85    102  ...   652
#
#    kpercen_y  bbpercen_y  iffbpercen_y  predictions  predictions_ranks  \
# 0      0.129       0.083         0.068    19.544442               13.0
# 1      0.197       0.115         0.025    22.782344                8.0
# 2      0.344       0.088         0.101    19.081286               16.0
# 3      0.111       0.108         0.148    26.317195                3.0
# 4      0.283       0.059         0.094    12.485643               36.0
# 5      0.262       0.108         0.068    24.088556                5.0
# 6      0.178       0.185         0.099    23.802312                6.0
# 7      0.167       0.072         0.132    19.196347               15.0
# 8      0.179       0.067         0.045    26.914748                2.0
# 9      0.299       0.112         0.063    14.287489               27.0
#
#    razz_ranks   avg  adp_ranks  rating_diff
# 0         4.0  12.6        7.0         -6.0
# 1         2.0   7.8        5.0         -3.0
# 2         6.0  20.2       12.5         -3.5
# 3         1.0   2.0        2.0         -1.0
# 4         7.0  18.0       10.5        -25.5
# 5         3.0   4.8        3.0         -2.0
# 6         5.0   1.0        1.0         -5.0
# 7         9.0  18.0       10.5         -4.5
# 8        12.0   8.4        6.0          4.0
# 9        11.0  41.6       20.0         -7.0
#
# [10 rows x 36 columns]

# %%
### Top 30 Hitters 2-year model Test
year = '2019'
SeasonOne = hitters.loc[ (hitters['season']==int(year))]
RazzSeason = hitters.loc[ (hitters['season']==(int(year)+1))]


SeasonOne = SeasonOne[["name", 'age','o_swingpercen','o_contactpercen','z_swingpercen','z_contactpercen','ops','r',
                      'rbi', 'hr','sb', 'pa', 'kpercen','bbpercen','iffbpercen']]
RazzSeason = RazzSeason[["name",'age','o_swingpercen','o_contactpercen','z_swingpercen','z_contactpercen','ops','r',
                      'rbi', 'hr','sb', 'pa', 'kpercen','bbpercen','iffbpercen']]



RazzSeason = RazzSeason.merge(SeasonOne , on='name')
X_test= RazzSeason[['age_y','o_swingpercen_x', 'o_contactpercen_x',
    'ops_x', 'rbi_x', 'hr_x',
   'sb_x', 'pa_x', 'kpercen_x', 'bbpercen_x', 'iffbpercen_x',
   'o_swingpercen_y', 'o_contactpercen_y', 'z_swingpercen_y',
   'z_contactpercen_y', 'ops_y', 'r_y', 'rbi_y', 'hr_y', 'sb_y', 'pa_y',
   'kpercen_y']]

# %%
### Top 30 Hitters 2-year model
Twenty_One_Prediction = model.predict(X_test)
RazzSeason['predicted_val'] = Twenty_One_Prediction

RazzSeason['predictions_ranks'] =RazzSeason['predicted_val'].rank(ascending=False)
RazzSeason =RazzSeason.sort_values(by=['predictions_ranks'], ascending=True)
RazzSeason.head(30)
# Out:
#                    name  age_x  o_swingpercen_x  o_contactpercen_x  \
# 14            Juan Soto     21            0.210              0.697
# 17     Ronald Acuna Jr.     22            0.235              0.650
# 11           Mike Trout     28            0.174              0.680
# 7       Freddie Freeman     30            0.282              0.747
# 36        Rafael Devers     23            0.423              0.650
# 52     Christian Yelich     28            0.203              0.455
# 9         Marcell Ozuna     29            0.325              0.539
# 141        Matt Chapman     27            0.269              0.495
# 28     Michael Conforto     27            0.277              0.578
# 5            Jose Abreu     33            0.364              0.589
# 160         Jorge Soler     28            0.251              0.478
# 19      Xander Bogaerts     27            0.278              0.660
# 3           Trea Turner     27            0.290              0.686
# 1          Jose Ramirez     27            0.259              0.806
# 171        Ozzie Albies     23            0.357              0.616
# 27          DJ LeMahieu     31            0.289              0.821
# 67       Anthony Rendon     30            0.208              0.704
# 16         Corey Seager     26            0.338              0.535
# 2          Mookie Betts     27            0.249              0.722
# 37          Pete Alonso     25            0.334              0.542
# 32       Cody Bellinger     24            0.299              0.714
# 6          Trevor Story     27            0.306              0.674
# 0    Fernando Tatis Jr.     21            0.296              0.630
# 12         Bryce Harper     27            0.311              0.579
# 30        J.T. Realmuto     29            0.281              0.610
# 33         Eloy Jimenez     23            0.411              0.628
# 21    Adalberto Mondesi     24            0.375              0.479
# 163        Alex Bregman     26            0.211              0.731
# 59      Travis d'Arnaud     31            0.354              0.545
# 20          Nelson Cruz     39            0.338              0.523
#
#      z_swingpercen_x  z_contactpercen_x  ops_x  r_x  rbi_x  hr_x  ...  r_y  \
# 14             0.614              0.889  1.185   39     37    13  ...  110
# 17             0.657              0.746  0.987   46     29    14  ...  127
# 11             0.599              0.874  0.993   41     46    17  ...  110
# 7              0.807              0.860  1.102   51     53    13  ...  113
# 36             0.751              0.756  0.793   32     43    11  ...  129
# 52             0.601              0.819  0.786   39     22    12  ...  100
# 9              0.690              0.836  1.067   38     56    18  ...   80
# 141            0.666              0.744  0.812   22     25    10  ...  102
# 28             0.686              0.868  0.927   40     31     9  ...   90
# 5              0.681              0.824  0.987   43     60    19  ...   85
# 160            0.587              0.782  0.769   17     24     8  ...   95
# 19             0.657              0.865  0.867   36     28    11  ...  110
# 3              0.719              0.883  0.982   46     41    12  ...   96
# 1              0.656              0.888  0.993   45     46    17  ...   68
# 171            0.851              0.849  0.773   21     19     6  ...  102
# 27             0.634              0.944  1.011   41     27    10  ...  109
# 67             0.683              0.937  0.915   29     31     9  ...  117
# 16             0.848              0.878  0.943   38     41    15  ...   82
# 2              0.593              0.956  0.927   47     39    16  ...  135
# 37             0.667              0.856  0.817   31     35    16  ...  103
# 32             0.721              0.832  0.789   33     30    12  ...  121
# 6              0.677              0.829  0.874   41     28    11  ...  111
# 0              0.715              0.792  0.937   50     45    17  ...   61
# 12             0.750              0.848  0.962   41     33    13  ...   98
# 30             0.698              0.803  0.840   33     32    11  ...   92
# 33             0.764              0.817  0.891   26     41    14  ...   69
# 21             0.780              0.733  0.710   33     22     6  ...   58
# 163            0.586              0.936  0.801   19     22     6  ...  122
# 59             0.691              0.825  0.919   19     34     9  ...   52
# 20             0.696              0.802  0.992   33     33    16  ...   81
#
#      rbi_y  hr_y  sb_y  pa_y  kpercen_y  bbpercen_y  iffbpercen_y  \
# 14     110    34    12   659      0.200       0.164         0.046
# 17     101    41    37   715      0.263       0.106         0.048
# 11     104    45    11   600      0.200       0.183         0.098
# 7      121    38     6   692      0.184       0.126         0.043
# 36     115    32     8   702      0.170       0.068         0.099
# 52      97    44    30   580      0.203       0.138         0.075
# 9       89    29    12   549      0.208       0.113         0.099
# 141     91    36     1   670      0.219       0.109         0.175
# 28      92    33     7   648      0.230       0.130         0.075
# 5      123    33     2   693      0.219       0.052         0.089
# 160    117    48     3   679      0.262       0.108         0.088
# 19     117    33     4   698      0.175       0.109         0.061
# 3       57    19    35   569      0.199       0.076         0.149
# 1       83    23    24   542      0.137       0.096         0.104
# 171     86    24    15   702      0.160       0.077         0.077
# 27     102    26     5   655      0.137       0.070         0.052
# 67     126    34     5   646      0.133       0.124         0.103
# 16      87    19     1   541      0.181       0.081         0.045
# 2       80    29    16   706      0.143       0.137         0.100
# 37     120    53     1   693      0.264       0.104         0.133
# 32     115    47    15   660      0.164       0.144         0.089
# 6       85    35    23   656      0.265       0.088         0.074
# 0       53    22    16   372      0.296       0.081         0.058
# 12     114    35    15   682      0.261       0.145         0.054
# 30      83    25     9   593      0.207       0.069         0.088
# 33      79    31     0   504      0.266       0.060         0.079
# 21      62     9    43   443      0.298       0.043         0.093
# 163    112    41     5   690      0.120       0.172         0.118
# 59      69    16     0   391      0.217       0.082         0.181
# 20     108    41     0   521      0.251       0.107         0.076
#
#      predicted_val  predictions_ranks
# 14       39.184302                1.0
# 17       37.903056                2.0
# 11       30.645552                3.0
# 7        29.969821                4.0
# 36       29.617466                5.0
# 52       28.137888                6.0
# 9        27.902452                7.0
# 141      25.025450                8.0
# 28       24.450904                9.0
# 5        24.184433               10.0
# 160      23.554363               11.0
# 19       23.474142               12.0
# 3        23.429479               13.0
# 1        23.240763               14.0
# 171      23.135333               15.0
# 27       22.728695               16.0
# 67       21.534942               17.0
# 16       21.353267               18.0
# 2        21.274160               19.0
# 37       20.868155               20.0
# 32       20.748962               21.0
# 6        20.352765               22.0
# 0        20.167990               23.0
# 12       19.326343               24.0
# 30       18.888288               25.0
# 33       18.793489               26.0
# 21       18.789631               27.0
# 163      18.672965               28.0
# 59       18.374697               29.0
# 20       18.150411               30.0
#
# [30 rows x 31 columns]
